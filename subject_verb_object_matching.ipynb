# %% [markdown]
# # Matching subject-verb-object-dependencies
# In the articles information is searched using subject-verb-object-dependencies.

# %%
import spacy
from spacy.matcher import DependencyMatcher
import pandas as pd

# %%
df = pd.read_csv('cleaned_fulltext_articles.csv')
list_text = df.loc[:110, 'fulltext'].dropna().tolist()
text = ' '.join(map(str, list_text))

# %%
# loads nlp pipeline without NER model
nlp = spacy.load('en_core_sci_lg', exclude='ner')

# %%
doc = nlp(text)

# %%
# defines list with nested dictionaries that contains the pattern of subject-object-root-relation
dep_pattern = [{'RIGHT_ID': 'verb', 'RIGHT_ATTRS': {'POS': 'VERB'}},
                 {'LEFT_ID': 'verb', 'REL_OP': '>', 'RIGHT_ID': 'subject', 'RIGHT_ATTRS': {'DEP': 'nsubj'}},
                 {'LEFT_ID': 'verb', 'REL_OP': '>', 'RIGHT_ID': 'd_object', 'RIGHT_ATTRS': {'DEP': 'dobj'}}
                ]

# %%
# # defines dependency matcher and add patterns
dep_matcher = DependencyMatcher(vocab=nlp.vocab)
dep_matcher.add('nsubj_verb_dobj', patterns=[dep_pattern])

# %%
# searches for matches in doc and saves them in list
dep_matches = dep_matcher(doc)

# %%
# loops through matches and prints strings of token positions
for match in dep_matches:
    pattern_name = match[0]
    matches = match[1]   
    match1, match2, match3 = matches[0], matches[1], matches[2]
    print(nlp.vocab[pattern_name].text, '\t', doc[match1], '...', doc[match2], '...', doc[match3])
# Out:
# nsubj_verb_dobj 	 describes ... article ... strain
# nsubj_verb_dobj 	 determined ... study ... sequence
# nsubj_verb_dobj 	 displayed ... trees ... positions
# nsubj_verb_dobj 	 represents ... T ... species
# nsubj_verb_dobj 	 showed ... it ... tolerance
# nsubj_verb_dobj 	 hydrolyse ... T ... gelatin
# nsubj_verb_dobj 	 contain ... genome ... gene
# nsubj_verb_dobj 	 produce ... T ... H2S
# nsubj_verb_dobj 	 contained ... species ... acids
# nsubj_verb_dobj 	 contained ... Most ... diphosphatidylglycerol
# nsubj_verb_dobj 	 contained ... T ... ubiquinone-8
# nsubj_verb_dobj 	 include ... lipids ... diphosphatidylglycerol
# nsubj_verb_dobj 	 include ... lipids ... aminophospholipid
# nsubj_verb_dobj 	 contains ... Mameliella ... species
# nsubj_verb_dobj 	 isolated ... we ... strain
# nsubj_verb_dobj 	 indicated ... which ... potential
# nsubj_verb_dobj 	 form ... strains ... colonies
# nsubj_verb_dobj 	 form ... strains ... h
# nsubj_verb_dobj 	 form ... strains ... C
# nsubj_verb_dobj 	 cultivated ... we ... T
# nsubj_verb_dobj 	 formed ... T ... clade
# nsubj_verb_dobj 	 represent ... T ... species
# nsubj_verb_dobj 	 predicted ... 4966 ... sequences
# nsubj_verb_dobj 	 contained ... assembly ... contigs
# nsubj_verb_dobj 	 represented ... they ... species
# nsubj_verb_dobj 	 exhibited ... T ... similarities
# nsubj_verb_dobj 	 accumulate ... strains ... poly-β-hydroxybutyrate
# nsubj_verb_dobj 	 accumulated ... T ... PHA
# nsubj_verb_dobj 	 accumulated ... T ... PHA
# nsubj_verb_dobj 	 distinguish ... we ... T
# nsubj_verb_dobj 	 draw ... we ... conclusion
# nsubj_verb_dobj 	 identified ... we ... features
# nsubj_verb_dobj 	 showed ... strains ... profiles
# nsubj_verb_dobj 	 included ... lipids ... phosphatidylethanolamine
# nsubj_verb_dobj 	 included ... lipids ... lipids
# nsubj_verb_dobj 	 contained ... none ... phosphatidylmonomethylethanolamine
# nsubj_verb_dobj 	 designed ... W.S.Z. ... study
# nsubj_verb_dobj 	 performed ... W.S.Z. ... experiments
# nsubj_verb_dobj 	 analysed ... W.S.Z. ... data
# nsubj_verb_dobj 	 supported ... Y.H. ... research
# nsubj_verb_dobj 	 wrote ... W.S.Z. ... paper
# nsubj_verb_dobj 	 share ... they ... features
# nsubj_verb_dobj 	 describe ... we ... strains
# nsubj_verb_dobj 	 indicated ... Analysis ... T
# nsubj_verb_dobj 	 ginsenosidivorans ... Niabella ... T
# nsubj_verb_dobj 	 showed ... tree ... positions
# nsubj_verb_dobj 	 contained ... genome ... contigs
# nsubj_verb_dobj 	 carries ... genome ... genes
# nsubj_verb_dobj 	 harboured ... genomes ... genes
# nsubj_verb_dobj 	 found ... genes ... genes
# nsubj_verb_dobj 	 found ... genes ... genes
# nsubj_verb_dobj 	 found ... genes ... genes
# nsubj_verb_dobj 	 found ... genes ... genes
# nsubj_verb_dobj 	 found ... genes ... genes
# nsubj_verb_dobj 	 found ... genes ... genes
# nsubj_verb_dobj 	 found ... gene ... genes
# nsubj_verb_dobj 	 utilize ... T ... xylan
# nsubj_verb_dobj 	 use ... neither ... chitin
# nsubj_verb_dobj 	 follows ... genes ... genes
# nsubj_verb_dobj 	 performed ... We ... sequencing
# nsubj_verb_dobj 	 contained ... genome ... contigs
# nsubj_verb_dobj 	 carries ... genome ... genes
# nsubj_verb_dobj 	 harboured ... genomes ... genes
# nsubj_verb_dobj 	 contained ... T ... acid
# nsubj_verb_dobj 	 contained ... profile ... phosphatidylethanolamine
# nsubj_verb_dobj 	 contained ... T ... acid
# nsubj_verb_dobj 	 contained ... profile ... diphosphatidylglycerol
# nsubj_verb_dobj 	 represent ... strains ... species
# nsubj_verb_dobj 	 include ... substrates ... gentiobiose
# nsubj_verb_dobj 	 contains ... profile ... phosphatidylethanolamine
# nsubj_verb_dobj 	 grow ... strain ... range
# nsubj_verb_dobj 	 include ... sources ... dextrin
# nsubj_verb_dobj 	 contains ... profile ... diphosphatidylglycerol
# nsubj_verb_dobj 	 thank ... We ... Zhou
# nsubj_verb_dobj 	 thank ... We ... Academy
# nsubj_verb_dobj 	 differentiate ... that ... T
# nsubj_verb_dobj 	 differentiate ... that ... T
# nsubj_verb_dobj 	 duplicates ... it ... epithet
# nsubj_verb_dobj 	 propose ... authors ... name
# nsubj_verb_dobj 	 grouped ... values ... them
# nsubj_verb_dobj 	 ranged ... content ... mol%
# nsubj_verb_dobj 	 differentiated ... absence ... strains
# nsubj_verb_dobj 	 permit ... results ... us
# nsubj_verb_dobj 	 publish ... purpose ... names
# nsubj_verb_dobj 	 send ... Authors ... copy
# nsubj_verb_dobj 	 provide ... authors ... evidence
# nsubj_verb_dobj 	 validates ... Inclusion ... publication
# nsubj_verb_dobj 	 presented ... we ... no.
# nsubj_verb_dobj 	 contained ... that ... inventory
# nsubj_verb_dobj 	 suggested ... we ... corrections
# nsubj_verb_dobj 	 suggested ... we ... corrections
# nsubj_verb_dobj 	 includes ... table ... names
# nsubj_verb_dobj 	 include ... This ... names
# nsubj_verb_dobj 	 involve ... that ... creation
# nsubj_verb_dobj 	 send ... Scientists ... file
# nsubj_verb_dobj 	 correct ... that ... names
# nsubj_verb_dobj 	 isolated ... Tissier ... organism
# nsubj_verb_dobj 	 isolated ... he ... organism
# nsubj_verb_dobj 	 isolated ... Prévot ... strain
# nsubj_verb_dobj 	 transferred ... Moore ... organism
# nsubj_verb_dobj 	 thank ... We ... Servaes
# nsubj_verb_dobj 	 obtained ... We ... isolates
# nsubj_verb_dobj 	 containing ... each ... g
# nsubj_verb_dobj 	 contained ... medium ... tryptone
# nsubj_verb_dobj 	 indicated ... color ... presence
# nsubj_verb_dobj 	 measured ... cells ... 0.8
# nsubj_verb_dobj 	 maintained ... cell ... shape
# nsubj_verb_dobj 	 described ... Tissier ... colonies
# nsubj_verb_dobj 	 found ... We ... colonies
# nsubj_verb_dobj 	 reported ... Prévot ... production
# nsubj_verb_dobj 	 fermented ... perfoetens ... glucose
# nsubj_verb_dobj 	 obtained ... We ... results
# nsubj_verb_dobj 	 found ... we ... content
# nsubj_verb_dobj 	 propose ... we ... B3/63
# nsubj_verb_dobj 	 prepare ... immunogens ... anti-D-LDH
# nsubj_verb_dobj 	 prepare ... immunogens ... sera
# nsubj_verb_dobj 	 describe ... we ... cross-reactions
# nsubj_verb_dobj 	 produced ... antiserum ... line
# nsubj_verb_dobj 	 gave ... extracts ... line
# nsubj_verb_dobj 	 produced ... viridescens ... cross-reaction
# nsubj_verb_dobj 	 shows ... Figure ... direction
# nsubj_verb_dobj 	 deduce ... we ... order
# nsubj_verb_dobj 	 displays ... which ... order
# nsubj_verb_dobj 	 confirm ... results ... similarity
# nsubj_verb_dobj 	 suggest ... results ... tree
# nsubj_verb_dobj 	 published ... al. ... data
# nsubj_verb_dobj 	 reported ... Garvie ... studies
# nsubj_verb_dobj 	 present ... We ... results
# nsubj_verb_dobj 	 produced ... DNA ... percentage
# nsubj_verb_dobj 	 contain ... groups ... strains
# nsubj_verb_dobj 	 reflect ... relations ... relationships
# nsubj_verb_dobj 	 reflect ... hybridizations ... relatedness
# nsubj_verb_dobj 	 establish ... we ... basis
# nsubj_verb_dobj 	 propose ... we ... subdivision
# nsubj_verb_dobj 	 suggest ... results ... rearrangements
# nsubj_verb_dobj 	 decreases ... procedure ... amount
# nsubj_verb_dobj 	 contained ... mixtures ... μg
# nsubj_verb_dobj 	 eluted ... solution ... DNA
# nsubj_verb_dobj 	 reas-sociate ... fragments ... themselves
# nsubj_verb_dobj 	 gave ... DNAs ... degree
# nsubj_verb_dobj 	 gave ... DNA ... degree
# nsubj_verb_dobj 	 give ... DNAs ... values
# nsubj_verb_dobj 	 separate ... we ... them
# nsubj_verb_dobj 	 produced ... experiments ... 45
# nsubj_verb_dobj 	 produced ... experiments ... hybridization
# nsubj_verb_dobj 	 showed ... DNAs ... degree
# nsubj_verb_dobj 	 hybridized ... DNAs ... %
# nsubj_verb_dobj 	 distinguish ... results ... species
# nsubj_verb_dobj 	 produced ... DNA ... yield
# nsubj_verb_dobj 	 exhibited ... strains ... degree
# nsubj_verb_dobj 	 produced ... others ... degree
# nsubj_verb_dobj 	 gave ... strain ... percentage
# nsubj_verb_dobj 	 suffered ... patient ... attacks
# nsubj_verb_dobj 	 described ... they ... which
# nsubj_verb_dobj 	 examined ... Manolov ... strains
# nsubj_verb_dobj 	 caused ... they ... keratoconjunctivitis
# nsubj_verb_dobj 	 supported ... Stenzel ... suggestion
# nsubj_verb_dobj 	 drew ... Szturm-Rubinsten ... attention
# nsubj_verb_dobj 	 considered ... group ... coli
# nsubj_verb_dobj 	 reported ... Shmi-lovitz ... importance
# nsubj_verb_dobj 	 utilise ... members ... citrate
# nsubj_verb_dobj 	 gave ... strains ... reaction
# nsubj_verb_dobj 	 include ... serovars ... nonmotile
# nsubj_verb_dobj 	 include ... serovars ... biotypes
# nsubj_verb_dobj 	 used ... Tekelieva ... techniques
# nsubj_verb_dobj 	 contained ... those ... sugars
# nsubj_verb_dobj 	 included ... strains ... representatives
# nsubj_verb_dobj 	 suffered ... Outbreak ... diarrhoea
# nsubj_verb_dobj 	 gave ... Antiserum ... cross-reactions
# nsubj_verb_dobj 	 gave ... suspension ... cross-reactions
# nsubj_verb_dobj 	 cause ... they ... which
# nsubj_verb_dobj 	 containing ... species ... acid
# nsubj_verb_dobj 	 containing ... both ... acid
# nsubj_verb_dobj 	 ferment ... it ... lactose
# nsubj_verb_dobj 	 shows ... Table ... results
# nsubj_verb_dobj 	 shows ... work ... homology
# nsubj_verb_dobj 	 considered ... Bryant ... T185
# nsubj_verb_dobj 	 confirms ... level ... opinion
# nsubj_verb_dobj 	 form ... strains ... group
# nsubj_verb_dobj 	 indicated ... studies ... presence
# nsubj_verb_dobj 	 indicate ... results ... absence
# nsubj_verb_dobj 	 await ... position ... investigations
# nsubj_verb_dobj 	 possess ... microorganisms ... wall
# nsubj_verb_dobj 	 occupy ... they ... niches
# nsubj_verb_dobj 	 infects ... it ... man
# nsubj_verb_dobj 	 includes ... Geodermatophilus ... microorganisms
# nsubj_verb_dobj 	 shown ... studies ... similarities
# nsubj_verb_dobj 	 play ... features ... role
# nsubj_verb_dobj 	 alter ... media ... results
# nsubj_verb_dobj 	 alter ... differences ... results
# nsubj_verb_dobj 	 indicate ... values ... divergency
# nsubj_verb_dobj 	 substantiate ... difference ... idea
# nsubj_verb_dobj 	 produced ... technique ... DNA
# nsubj_verb_dobj 	 affect ... that ... temperatures
# nsubj_verb_dobj 	 provided ... hybridization ... approaches
# nsubj_verb_dobj 	 provided ... methods ... approaches
# nsubj_verb_dobj 	 define ... one ... species
# nsubj_verb_dobj 	 expect ... Put ... members
# nsubj_verb_dobj 	 expect ... we ... members
# nsubj_verb_dobj 	 shown ... Analysis ... existence
# nsubj_verb_dobj 	 shown ... Analysis ... term
# nsubj_verb_dobj 	 call ... we ... which
# nsubj_verb_dobj 	 indicate ... findings ... degree
# nsubj_verb_dobj 	 shown ... molecule ... differences
# nsubj_verb_dobj 	 shown ... Brown ... differences
# nsubj_verb_dobj 	 demonstrated ... He ... differences
# nsubj_verb_dobj 	 mutans ... aldolases ... ”
# nsubj_verb_dobj 	 mutans ... S. ... groups
# nsubj_verb_dobj 	 augment ... which ... those
# nsubj_verb_dobj 	 found ... Shklair ... susceptibility
# nsubj_verb_dobj 	 measure ... Cells ... μm
# nsubj_verb_dobj 	 thank ... I ... Clewell
# nsubj_verb_dobj 	 deposited ... Sims ... strain
# nsubj_verb_dobj 	 resemble ... characteristics ... those
# nsubj_verb_dobj 	 described ... Edwardsson ... NCTC
# nsubj_verb_dobj 	 fermented ... which ... mannitol
# nsubj_verb_dobj 	 hy-drolyze ... It ... arginine
# nsubj_verb_dobj 	 tolerate ... It ... C
# nsubj_verb_dobj 	 acidified ... It ... milk
# nsubj_verb_dobj 	 mutans ... micrographs ... strains
# nsubj_verb_dobj 	 show ... GS5 ... cells
# nsubj_verb_dobj 	 show ... walls ... layer
# nsubj_verb_dobj 	 ferment ... strains ... melibiose
# nsubj_verb_dobj 	 share ... Strains ... sequences
# nsubj_verb_dobj 	 produce ... cells ... polysaccharide
# nsubj_verb_dobj 	 produces ... FA1 ... ammonia
# nsubj_verb_dobj 	 produced ... It ... acid
# nsubj_verb_dobj 	 ferment ... It ... arabinose
# nsubj_verb_dobj 	 react ... strains ... antiserum
# nsubj_verb_dobj 	 ate ... that ... cane
# nsubj_verb_dobj 	 produces ... SL1 ... acid
# nsubj_verb_dobj 	 split ... it ... arginine
# nsubj_verb_dobj 	 show ... strains ... cocci
# nsubj_verb_dobj 	 give ... strains ... reaction
# nsubj_verb_dobj 	 share ... strains ... sequences
# nsubj_verb_dobj 	 ferment ... strains ... sorbitol
# nsubj_verb_dobj 	 fermented ... 14H ... sorbitol
# nsubj_verb_dobj 	 ate ... that ... cane
# nsubj_verb_dobj 	 form ... organisms ... taxon
# nsubj_verb_dobj 	 divided ... Goodfellow ... strains
# nsubj_verb_dobj 	 share ... taxospecies ... homology
# nsubj_verb_dobj 	 formed ... representatives ... groups
# nsubj_verb_dobj 	 formed ... la ... groups
# nsubj_verb_dobj 	 extended ... we ... assays
# nsubj_verb_dobj 	 reference ... degree ... system
# nsubj_verb_dobj 	 reference ... degree ... agreement
# nsubj_verb_dobj 	 support ... data ... view
# nsubj_verb_dobj 	 forms ... astéroïdes ... taxon
# nsubj_verb_dobj 	 reference ... astéroïdes ... system
# nsubj_verb_dobj 	 formed ... representatives ... group
# nsubj_verb_dobj 	 shared ... strains ... %
# nsubj_verb_dobj 	 confirm ... findings ... study
# nsubj_verb_dobj 	 forms ... 1A ... taxon
# nsubj_verb_dobj 	 share ... 1A ... similarity
# nsubj_verb_dobj 	 share ... strains ... similarity
# nsubj_verb_dobj 	 form ... representatives ... group
# nsubj_verb_dobj 	 showed ... representative ... homology
# nsubj_verb_dobj 	 share ... they ... homology
# nsubj_verb_dobj 	 showed ... preparations ... EimlE2w
# nsubj_verb_dobj 	 showed ... preparations ... 1.9
# nsubj_verb_dobj 	 indicated ... Reaction ... acid
# nsubj_verb_dobj 	 bound ... DNA ... DNA
# nsubj_verb_dobj 	 bound ... preparations ... amounts
# nsubj_verb_dobj 	 exhibited ... strains ... degree
# nsubj_verb_dobj 	 exhibited ... strains ... degree
# nsubj_verb_dobj 	 showed ... preparations ... degree
# nsubj_verb_dobj 	 bound ... four ... %
# nsubj_verb_dobj 	 bound ... strain ... %
# nsubj_verb_dobj 	 thank ... I ... Pfenning
# nsubj_verb_dobj 	 contained ... plates ... colonies
# nsubj_verb_dobj 	 contained ... plates ... each
# nsubj_verb_dobj 	 contained ... Most ... thought
# nsubj_verb_dobj 	 contained ... BGM ... extract
# nsubj_verb_dobj 	 contained ... TES ... 7H20
# nsubj_verb_dobj 	 contained ... media ... CaCO3
# nsubj_verb_dobj 	 contained ... medium ... agar
# nsubj_verb_dobj 	 support ... BGM ... growth
# nsubj_verb_dobj 	 show ... Figures ... photomicrographs
# nsubj_verb_dobj 	 measured ... rods ... 0.7
# nsubj_verb_dobj 	 contained ... cells ... regions
# nsubj_verb_dobj 	 shows ... Figure ... micrograph
# nsubj_verb_dobj 	 produced ... strains ... colonies
# nsubj_verb_dobj 	 contained ... colonies ... cells
# nsubj_verb_dobj 	 enhanced ... Refrigeration ... tendency
# nsubj_verb_dobj 	 provided ... maltose ... concentration
# nsubj_verb_dobj 	 showed ... organisms ... responses
# nsubj_verb_dobj 	 fermented ... organisms ... melezitose
# nsubj_verb_dobj 	 ferment ... They ... mannose
# nsubj_verb_dobj 	 hydrolyze ... organism ... starch
# nsubj_verb_dobj 	 contained ... R ... cells
# nsubj_verb_dobj 	 measured ... which ... 0.7
# nsubj_verb_dobj 	 contained ... V ... cells
# nsubj_verb_dobj 	 form ... that ... vacuoles
# nsubj_verb_dobj 	 mention ... One ... genera
# nsubj_verb_dobj 	 fit ... isolates ... description
# nsubj_verb_dobj 	 contains ... Ancalomicrobium ... species
# nsubj_verb_dobj 	 form ... Pelonema ... filaments
# nsubj_verb_dobj 	 consider ... One ... relationship
# nsubj_verb_dobj 	 carry ... they ... respiration
# nsubj_verb_dobj 	 eliminate ... characteristics ... isolates
# nsubj_verb_dobj 	 carry ... isolates ... respiration
# nsubj_verb_dobj 	 chalky ... Colonies ... white
# nsubj_verb_dobj 	 show ... Cultures ... cells
# nsubj_verb_dobj 	 occurs ... growth ... C
# nsubj_verb_dobj 	 ferment ... agar ... mannose
# nsubj_verb_dobj 	 spans ... that ... kingdom
# nsubj_verb_dobj 	 call ... Zuckerkandl ... what
# nsubj_verb_dobj 	 necessitate ... considerations ... care
# nsubj_verb_dobj 	 expect ... one ... degree
# nsubj_verb_dobj 	 hold ... mechanisms ... potential
# nsubj_verb_dobj 	 form ... both ... ribo-somes
# nsubj_verb_dobj 	 contain ... they ... regions
# nsubj_verb_dobj 	 examine ... one ... extent
# nsubj_verb_dobj 	 provide ... nucleotides ... classification
# nsubj_verb_dobj 	 produces ... This ... catalog
# nsubj_verb_dobj 	 allow ... which ... examination
# nsubj_verb_dobj 	 summarizes ... Table ... families
# nsubj_verb_dobj 	 defined ... clustering ... dendrogram
# nsubj_verb_dobj 	 allowed ... comparison ... determination
# nsubj_verb_dobj 	 represented ... families ... positions
# nsubj_verb_dobj 	 represented ... sequences ... positions
# nsubj_verb_dobj 	 reaffirm ... many ... points
# nsubj_verb_dobj 	 indicate ... 32 ... Sporolactobacillus
# nsubj_verb_dobj 	 emphasize ... families ... interrelatedness
# nsubj_verb_dobj 	 reflect ... numbers ... group
# nsubj_verb_dobj 	 allow ... families ... insight
# nsubj_verb_dobj 	 affected ... it ... RNAs
# nsubj_verb_dobj 	 give ... method ... results
# nsubj_verb_dobj 	 classify ... They ... Bacillus
# nsubj_verb_dobj 	 provided ... results ... evidence
# nsubj_verb_dobj 	 offers ... cataloging ... advantages
# nsubj_verb_dobj 	 requires ... it ... expertise
# nsubj_verb_dobj 	 relates ... that ... number
# nsubj_verb_dobj 	 receive ... matters ... attention
# nsubj_verb_dobj 	 thank ... We ... Zablen
# nsubj_verb_dobj 	 s ... B. ... tear
# nsubj_verb_dobj 	 involves ... analysis ... electrophoresis
# nsubj_verb_dobj 	 comprises ... fingerprint ... pattern
# nsubj_verb_dobj 	 produce ... which ... number
# nsubj_verb_dobj 	 represented ... column ... one
# nsubj_verb_dobj 	 required ... aspects ... care
# nsubj_verb_dobj 	 identified ... approach ... portion
# nsubj_verb_dobj 	 alleviated ... it ... question
# nsubj_verb_dobj 	 investigated ... al. ... relatedness
# nsubj_verb_dobj 	 gave ... SD-DNA ... data
# nsubj_verb_dobj 	 represents ... Table ... similarity
# nsubj_verb_dobj 	 provide ... results ... evidence
# nsubj_verb_dobj 	 thank ... We ... Sakagami
# nsubj_verb_dobj 	 attended ... Holdeman ... sessions
# nsubj_verb_dobj 	 attended ... Sutter ... sessions
# nsubj_verb_dobj 	 discussed ... Subcommittee ... list
# nsubj_verb_dobj 	 heard ... Subcommittee ... reports
# nsubj_verb_dobj 	 include ... work ... comparison
# nsubj_verb_dobj 	 tained ... Bacteroides ... number
# nsubj_verb_dobj 	 constitute ... which ... genus
# nsubj_verb_dobj 	 expressed ... tee ... appreciation
# nsubj_verb_dobj 	 stressed ... They ... importance
# nsubj_verb_dobj 	 carry ... who ... research
# nsubj_verb_dobj 	 sent ... members ... proxies
# nsubj_verb_dobj 	 discussed ... Runyon ... problem
# nsubj_verb_dobj 	 announced ... Runyon ... retirement
# nsubj_verb_dobj 	 expressed ... committee ... thanks
# nsubj_verb_dobj 	 entertained ... floor ... nominations
# nsubj_verb_dobj 	 proposed ... Stanford ... name
# nsubj_verb_dobj 	 create ... reapplication ... confusion
# nsubj_verb_dobj 	 include ... we ... following
# nsubj_verb_dobj 	 included ... Proposals ... Prague
# nsubj_verb_dobj 	 made ... Murray ... suggestions
# nsubj_verb_dobj 	 stated ... Allsopp ... “
# nsubj_verb_dobj 	 comprise ... which ... Bacteria
# nsubj_verb_dobj 	 includes ... which ... organisms
# nsubj_verb_dobj 	 included ... Whittaker ... procaryotes
# nsubj_verb_dobj 	 accepted ... Copeland ... Monera
# nsubj_verb_dobj 	 implies ... which ... association
# nsubj_verb_dobj 	 ignored ... Bacteriologists ... name
# nsubj_verb_dobj 	 accepted ... Stanier ... it
# nsubj_verb_dobj 	 proposed ... Margulis ... Prokaryota
# nsubj_verb_dobj 	 suggest ... Murray ... taxon
# nsubj_verb_dobj 	 suggest ... “ ... taxon
# nsubj_verb_dobj 	 sees ... Lewin ... point
# nsubj_verb_dobj 	 consider ... We ... procaryotes
# nsubj_verb_dobj 	 present ... authors ... view
# nsubj_verb_dobj 	 provide ... Studies ... data
# nsubj_verb_dobj 	 coin ... who ... them
# nsubj_verb_dobj 	 possesses ... which ... type
# nsubj_verb_dobj 	 possesses ... which ... type
# nsubj_verb_dobj 	 lacks ... which ... wall
# nsubj_verb_dobj 	 propose ... we ... name
# nsubj_verb_dobj 	 precede ... division ... Mollicutes
# nsubj_verb_dobj 	 contains ... Gracilicutes ... classes
# nsubj_verb_dobj 	 comprises ... Photobacteria ... subclasses
# nsubj_verb_dobj 	 produce ... which ... oxygen
# nsubj_verb_dobj 	 suggested ... Lewin ... division
# nsubj_verb_dobj 	 contain ... that ... chlorophylls
# nsubj_verb_dobj 	 contain ... that ... a
# nsubj_verb_dobj 	 belong ... these ... Oxyphotobacteriae
# nsubj_verb_dobj 	 comprise ... subclass ... order
# nsubj_verb_dobj 	 comprise ... subclass ... nov.
# nsubj_verb_dobj 	 carry ... that ... metabolism
# nsubj_verb_dobj 	 comprise ... subclass ... orders
# nsubj_verb_dobj 	 provided ... authors ... names
# nsubj_verb_dobj 	 involves ... multiplication ... growth
# nsubj_verb_dobj 	 possess ... that ... photosystems
# nsubj_verb_dobj 	 contain ... Cells ... chlorophyll
# nsubj_verb_dobj 	 contain ... Cells ... a
# nsubj_verb_dobj 	 contain ... Cells ... Cells
# nsubj_verb_dobj 	 bacteriales ... Cyano ... Cyanobacteria
# nsubj_verb_dobj 	 contain ... Some ... phycoerythrin
# nsubj_verb_dobj 	 perform ... photoautotrophs ... photosynthesis
# nsubj_verb_dobj 	 perform ... some ... photosynthesis
# nsubj_verb_dobj 	 form ... cyanobacteria ... cyanophycin
# nsubj_verb_dobj 	 produce ... cyanobacteria ... cells
# nsubj_verb_dobj 	 form ... cyanobacteria ... cells
# nsubj_verb_dobj 	 contain ... Lewin ... chlorophylls
# nsubj_verb_dobj 	 contain ... Lewin ... a
# nsubj_verb_dobj 	 contain ... 217,Cells ... chlorophylls
# nsubj_verb_dobj 	 contain ... 217,Cells ... a
# nsubj_verb_dobj 	 contain ... Procaryotes ... bacteriochlorophyll
# nsubj_verb_dobj 	 contains ... order ... families
# nsubj_verb_dobj 	 contains ... order ... families
# nsubj_verb_dobj 	 exhibit ... they ... motility
# nsubj_verb_dobj 	 show ... organisms ... gliding
# nsubj_verb_dobj 	 having ... Procaryotes ... type
# nsubj_verb_dobj 	 produce ... some ... spores
# nsubj_verb_dobj 	 cover ... that ... some
# nsubj_verb_dobj 	 lack ... that ... wall
# nsubj_verb_dobj 	 includes ... it ... fission
# nsubj_verb_dobj 	 made ... who ... suggestions
# nsubj_verb_dobj 	 present ... communication ... evidence
# nsubj_verb_dobj 	 presented ... results ... allow
# nsubj_verb_dobj 	 form ... members ... Q
# nsubj_verb_dobj 	 contain ... strains ... Q
# nsubj_verb_dobj 	 differentiates ... lack ... organisms
# nsubj_verb_dobj 	 form ... that ... Q
# nsubj_verb_dobj 	 form ... that ... quinones
# nsubj_verb_dobj 	 produces ... that ... gas
# nsubj_verb_dobj 	 contained ... organisms ... quinones
# nsubj_verb_dobj 	 contain ... Actinobacillus ... DMK
# nsubj_verb_dobj 	 contain ... organisms ... DMK
# nsubj_verb_dobj 	 produces ... pneumotropica ... DMK
# nsubj_verb_dobj 	 contain ... organisms ... Q
# nsubj_verb_dobj 	 produced ... actinoides ... MK
# nsubj_verb_dobj 	 exhibited ... Actinobacillus ... activities
# nsubj_verb_dobj 	 produce ... that ... pigments
# nsubj_verb_dobj 	 uses ... meningosepticum ... menaquinone
# nsubj_verb_dobj 	 contains ... aquatile ... ubiquinone
# nsubj_verb_dobj 	 define ... patterns ... groups
# nsubj_verb_dobj 	 presented ... data ... lead
# nsubj_verb_dobj 	 comprise ... Cytophaga ... organisms
# nsubj_verb_dobj 	 produced ... culture ... naphthoquinones
# nsubj_verb_dobj 	 deserves ... stimulation ... attention
# nsubj_verb_dobj 	 indicates ... phenomenon ... presence
# nsubj_verb_dobj 	 involves ... system ... cytochromes
# nsubj_verb_dobj 	 supplemented ... medium ... D-(+)-glucose
# nsubj_verb_dobj 	 contained ... some ... amounts
# nsubj_verb_dobj 	 received ... tubes ... inocula
# nsubj_verb_dobj 	 contained ... that ... medium
# nsubj_verb_dobj 	 contains ... ii ... strains
# nsubj_verb_dobj 	 proposed ... Shope ... name
# nsubj_verb_dobj 	 found ... who ... isolates
# nsubj_verb_dobj 	 chose ... Nicolet ... name
# nsubj_verb_dobj 	 chose ... Nicolet ... parahaemolyticus
# nsubj_verb_dobj 	 revealed ... study ... number
# nsubj_verb_dobj 	 established ... Pittman ... parahaemolyticus
# nsubj_verb_dobj 	 raised ... findings ... questions
# nsubj_verb_dobj 	 suggested ... origin ... identity
# nsubj_verb_dobj 	 included ... characteristics ... ability
# nsubj_verb_dobj 	 confirm ... findings ... suggestion
# nsubj_verb_dobj 	 included ... group ... strains
# nsubj_verb_dobj 	 deserves ... it ... recognition
# nsubj_verb_dobj 	 consider ... we ... name
# nsubj_verb_dobj 	 justify ... differences ... recognition
# nsubj_verb_dobj 	 acknowledge ... We ... receipt
# nsubj_verb_dobj 	 comprised ... group ... strains
# nsubj_verb_dobj 	 included ... group ... strains
# nsubj_verb_dobj 	 produced ... Cultures ... zones
# nsubj_verb_dobj 	 produced ... None ... hemolysin
# nsubj_verb_dobj 	 revealed ... tests ... relationship
# nsubj_verb_dobj 	 lost ... strains ... antigen
# nsubj_verb_dobj 	 showed ... strains ... tendency
# nsubj_verb_dobj 	 await ... rhizobia ... designation
# nsubj_verb_dobj 	 made ... introduction ... survey
# nsubj_verb_dobj 	 designated ... we ... acquisition
# nsubj_verb_dobj 	 maintained ... succession ... collection
# nsubj_verb_dobj 	 maintained ... Haynes ... collection
# nsubj_verb_dobj 	 indicates ... record ... plant
# nsubj_verb_dobj 	 require ... rhizobia ... biotin
# nsubj_verb_dobj 	 affect ... that ... growth
# nsubj_verb_dobj 	 display ... strains ... characteristics
# nsubj_verb_dobj 	 includes ... list ... strains
# nsubj_verb_dobj 	 yielded ... they ... type
# nsubj_verb_dobj 	 contained ... solution ... mg
# nsubj_verb_dobj 	 contained ... that ... ml
# nsubj_verb_dobj 	 contained ... medium ... Acids
# nsubj_verb_dobj 	 contained ... vials ... ml
# nsubj_verb_dobj 	 gave ... leakage ... tension
# nsubj_verb_dobj 	 cultivate ... medium ... strains
# nsubj_verb_dobj 	 produced ... L-259 ... nmol
# nsubj_verb_dobj 	 yielded ... subfamilies ... rhizobia
# nsubj_verb_dobj 	 gave ... that ... numbers
# nsubj_verb_dobj 	 gave ... 202 ... growth
# nsubj_verb_dobj 	 reduced ... majority ... acetylene
# nsubj_verb_dobj 	 reduced ... % ... acetylene
# nsubj_verb_dobj 	 reduced ... majority ... acetylene
# nsubj_verb_dobj 	 indicates ... diversity ... limitation
# nsubj_verb_dobj 	 survived ... 4 ... procedure
# nsubj_verb_dobj 	 permit ... data ... designation
# nsubj_verb_dobj 	 inhabit ... that ... bodies
# nsubj_verb_dobj 	 encountered ... we ... bacteria
# nsubj_verb_dobj 	 represent ... strains ... species
# nsubj_verb_dobj 	 prompted ... variation ... us
# nsubj_verb_dobj 	 shows ... Figure ... morphology
# nsubj_verb_dobj 	 produces ... it ... pigment
# nsubj_verb_dobj 	 produces ... Runella ... acid
# nsubj_verb_dobj 	 meant ... which ... writing
# nsubj_verb_dobj 	 measure ... cells ... 0.9
# nsubj_verb_dobj 	 contain ... Colonies ... pink
# nsubj_verb_dobj 	 made ... technique ... use
# nsubj_verb_dobj 	 gave ... Characteristics ... description
# nsubj_verb_dobj 	 gave ... Comparison ... description
# nsubj_verb_dobj 	 reported ... Ross ... results
# nsubj_verb_dobj 	 constitutes ... disease ... problem
# nsubj_verb_dobj 	 contained ... cuvettes ... μg
# nsubj_verb_dobj 	 pumped ... that ... water
# nsubj_verb_dobj 	 differ ... they ... little
# nsubj_verb_dobj 	 yielded ... isolates ... tests
# nsubj_verb_dobj 	 gave ... % ... reactions
# nsubj_verb_dobj 	 fermented ... strains ... lactose
# nsubj_verb_dobj 	 gave ... all ... tests
# nsubj_verb_dobj 	 utilized ... All ... glucose
# nsubj_verb_dobj 	 contained ... sequences ... bases
# nsubj_verb_dobj 	 showed ... sequences ... D.
# nsubj_verb_dobj 	 made ... who ... stains
# nsubj_verb_dobj 	 yielded ... all ... tests
# nsubj_verb_dobj 	 possessed ... strains ... antigen
# nsubj_verb_dobj 	 reveals ... Examination ... similarities
# nsubj_verb_dobj 	 reveals ... enterocolitica ... similarities
# nsubj_verb_dobj 	 share ... species ... relatedness
# nsubj_verb_dobj 	 exhibit ... bacteria ... level
# nsubj_verb_dobj 	 belong ... bacteria ... Serratia
# nsubj_verb_dobj 	 studied ... Strains ... characteristics
# nsubj_verb_dobj 	 studied ... Strains ... nov.
# nsubj_verb_dobj 	 exhibits ... A3 ... activity
# nsubj_verb_dobj 	 Rule ... name ... 25b
# nsubj_verb_dobj 	 concerns ... report ... comparison
# nsubj_verb_dobj 	 suggested ... concerns ... group
# nsubj_verb_dobj 	 revive ... we ... name
# nsubj_verb_dobj 	 applied ... Giolitti ... name
# nsubj_verb_dobj 	 acknowledges ... Skarbek ... Fellowships
# nsubj_verb_dobj 	 thank ... authors ... Mauseth
# nsubj_verb_dobj 	 exhibited ... AUW-83 ... chains
# nsubj_verb_dobj 	 exhibited ... M ... spores
# nsubj_verb_dobj 	 illustrating ... micrographs ... characteristics
# nsubj_verb_dobj 	 sporulating ... color ... growth
# nsubj_verb_dobj 	 gave ... which ... response
# nsubj_verb_dobj 	 recorded ... Growth ... ±
# nsubj_verb_dobj 	 indicates ... which ... utilization
# nsubj_verb_dobj 	 indicates ... reading ... utilization
# nsubj_verb_dobj 	 gave ... strain ... reaction
# nsubj_verb_dobj 	 produced ... it ... pigment
# nsubj_verb_dobj 	 utilized ... it ... component
# nsubj_verb_dobj 	 permit ... cultures ... control
# nsubj_verb_dobj 	 displayed ... Strain ... activity
# nsubj_verb_dobj 	 exhibited ... AUW-83 ... pattern
# nsubj_verb_dobj 	 presented ... M ... pattern
# nsubj_verb_dobj 	 presented ... M ... antibiotics
# nsubj_verb_dobj 	 produce ... strains ... antibiotics
# nsubj_verb_dobj 	 produce ... others ... A3
# nsubj_verb_dobj 	 contains ... which ... nitrogen
# nsubj_verb_dobj 	 includes ... spectrum ... antagonism
# nsubj_verb_dobj 	 produce ... they ... which
# nsubj_verb_dobj 	 shows ... AUW-83 ... susceptibility
# nsubj_verb_dobj 	 produces ... it ... A3
# nsubj_verb_dobj 	 recognized ... group ... types
# nsubj_verb_dobj 	 produce ... which ... them
# nsubj_verb_dobj 	 present ... purpose ... features
# nsubj_verb_dobj 	 distinguish ... that ... it
# nsubj_verb_dobj 	 produce ... which ... chromomycins
# nsubj_verb_dobj 	 proposed ... who ... use
# nsubj_verb_dobj 	 tolerate ... % ... chloride
# nsubj_verb_dobj 	 tolerate ... species ... chloride
# nsubj_verb_dobj 	 contravene ... publications ... 25b
# nsubj_verb_dobj 	 acknowledges ... Skarbek ... Fellowships
# nsubj_verb_dobj 	 thank ... authors ... Mauseth
# nsubj_verb_dobj 	 thank ... authors ... mycins
# nsubj_verb_dobj 	 produced ... strains ... antibiotics
# nsubj_verb_dobj 	 illustrating ... micrographs ... morphologies
# nsubj_verb_dobj 	 illustrating ... graphs ... types
# nsubj_verb_dobj 	 illustrating ... micrographs ... types
# nsubj_verb_dobj 	 sporulating ... colors ... growth
# nsubj_verb_dobj 	 exhibited ... no. ... coloration
# nsubj_verb_dobj 	 exhibited ... S-1081 ... coloration
# nsubj_verb_dobj 	 exhibited ... extracts ... spectra
# nsubj_verb_dobj 	 invade ... species ... viscera
# nsubj_verb_dobj 	 require ... ulcerans ... period
# nsubj_verb_dobj 	 received ... She ... treatment
# nsubj_verb_dobj 	 showed ... biopsy ... disease
# nsubj_verb_dobj 	 indicated ... Lymphography ... involvement
# nsubj_verb_dobj 	 produce ... questioning ... information
# nsubj_verb_dobj 	 revealed ... analysis ... pancytopenia
# nsubj_verb_dobj 	 showed ... Histology ... foci
# nsubj_verb_dobj 	 reaching ... some ... size
# nsubj_verb_dobj 	 showed ... which ... granulocytes
# nsubj_verb_dobj 	 indicate ... occurrence ... spread
# nsubj_verb_dobj 	 healed ... lesions ... one
# nsubj_verb_dobj 	 leaving ... some ... scars
# nsubj_verb_dobj 	 showed ... analysis ... pancytopenia
# nsubj_verb_dobj 	 stain ... that ... acid
# nsubj_verb_dobj 	 requires ... organism ... hemoglobin
# nsubj_verb_dobj 	 proposed ... Marks ... system
# nsubj_verb_dobj 	 supports ... ratio ... contention
# nsubj_verb_dobj 	 examined ... we ... ulcerans
# nsubj_verb_dobj 	 recall ... results ... reaction
# nsubj_verb_dobj 	 produces ... avium ... that
# nsubj_verb_dobj 	 resembles ... disease ... tuberculosis
# nsubj_verb_dobj 	 recalls ... requirement ... mutants
# nsubj_verb_dobj 	 regard ... we ... organism
# nsubj_verb_dobj 	 propose ... which ... name
# nsubj_verb_dobj 	 propose ... we ... name
# nsubj_verb_dobj 	 resisted ... that ... attempts
# nsubj_verb_dobj 	 indicate ... authors ... media
# nsubj_verb_dobj 	 stimulate ... communication ... use
# nsubj_verb_dobj 	 thank ... We ... Rozenszajn
# nsubj_verb_dobj 	 received ... D.S. ... assistance
# nsubj_verb_dobj 	 received ... D.S. ... requests
# nsubj_verb_dobj 	 included ... media ... medium
# nsubj_verb_dobj 	 defined ... Sula ... medium
# nsubj_verb_dobj 	 bouraud ... Sa- ... agar
# nsubj_verb_dobj 	 yielded ... samples ... growth
# nsubj_verb_dobj 	 stimulate ... addition ... growth
# nsubj_verb_dobj 	 replace ... following ... hemin
# nsubj_verb_dobj 	 replace ... following ... charcoal
# nsubj_verb_dobj 	 induces ... that ... pigmentation
# nsubj_verb_dobj 	 alter ... subculture ... limits
# nsubj_verb_dobj 	 developed ... organism ... colonies
# nsubj_verb_dobj 	 gave ... Most ... results
# nsubj_verb_dobj 	 produce ... it ... catalase
# nsubj_verb_dobj 	 summarizes ... Table ... susceptibility
# nsubj_verb_dobj 	 cause ... Inoculations ... changes
# nsubj_verb_dobj 	 cause ... pigs ... changes
# nsubj_verb_dobj 	 survived ... most ... period
# nsubj_verb_dobj 	 developed ... tissue ... granulomatosis
# nsubj_verb_dobj 	 caused ... that ... obliteration
# nsubj_verb_dobj 	 showed ... Histology ... rods
# nsubj_verb_dobj 	 isolated ... we ... acholeplasmas
# nsubj_verb_dobj 	 showed ... all ... features
# nsubj_verb_dobj 	 contains ... which ... strains
# nsubj_verb_dobj 	 thank ... I ... Lemcke
# nsubj_verb_dobj 	 der ... Kirchhoff ... Hannover
# nsubj_verb_dobj 	 hydrolyzed ... saline ... lactalbumin
# nsubj_verb_dobj 	 exhibited ... Colonies ... morphology
# nsubj_verb_dobj 	 reached ... Growth ... maximum
# nsubj_verb_dobj 	 showed ... microscopy ... organisms
# nsubj_verb_dobj 	 passed ... All ... 450-
# nsubj_verb_dobj 	 passed ... All ... filters
# nsubj_verb_dobj 	 showed ... All ... features
# nsubj_verb_dobj 	 developed ... colonies ... coloration
# nsubj_verb_dobj 	 showed ... Strain ... cross-reaction
# nsubj_verb_dobj 	 gave ... reactions ... eight
# nsubj_verb_dobj 	 propose ... we ... name
# nsubj_verb_dobj 	 exhibited ... strains ... degree
# nsubj_verb_dobj 	 used ... autotrophicum ... fructose
# nsubj_verb_dobj 	 used ... paradoxus ... monosaccharides
# nsubj_verb_dobj 	 resemble ... strains ... strain
# nsubj_verb_dobj 	 lost ... which ... ability
# nsubj_verb_dobj 	 differ ... they ... Pseudomonas
# nsubj_verb_dobj 	 report ... authors ... conditions
# nsubj_verb_dobj 	 contained ... GA3 ... amounts
# nsubj_verb_dobj 	 produced ... ficans ... c-d
# nsubj_verb_dobj 	 disclosed ... tests ... relations
# nsubj_verb_dobj 	 transcend ... antigens ... boundaries
# nsubj_verb_dobj 	 gave ... antiserum ... cross-reaction
# nsubj_verb_dobj 	 provide ... data ... help
# nsubj_verb_dobj 	 gave ... finding ... support
# nsubj_verb_dobj 	 possesses ... Chemoorganotrophic ... hydrogenase
# nsubj_verb_dobj 	 reduce ... which ... dinucleotide
# nsubj_verb_dobj 	 made ... who ... spectra
# nsubj_verb_dobj 	 thank ... We ... Knackmuss
# nsubj_verb_dobj 	 received ... We ... help
# nsubj_verb_dobj 	 no. ... Schiill ... paper
# nsubj_verb_dobj 	 reached ... length ... µm
# nsubj_verb_dobj 	 d-(+)- ... carbohydrates ... galactose
# nsubj_verb_dobj 	 ate ... L-(+)-rhamnose ... tarate
# nsubj_verb_dobj 	 allows ... that ... growth
# nsubj_verb_dobj 	 support ... that ... growth
# nsubj_verb_dobj 	 produced ... strains ... acid
# nsubj_verb_dobj 	 developed ... strains ... brown
# nsubj_verb_dobj 	 contains ... which ... glycerol
# nsubj_verb_dobj 	 revealed ... sections ... characteristic
# nsubj_verb_dobj 	 showed ... extracts ... trace
# nsubj_verb_dobj 	 required ... pigments ... acidification
# nsubj_verb_dobj 	 contain ... majority ... mixture
# nsubj_verb_dobj 	 synthesizes ... pseudoflava ... series
# nsubj_verb_dobj 	 identified ... al. ... pigments
# nsubj_verb_dobj 	 reveal ... typing ... relationship
# nsubj_verb_dobj 	 agglutinated ... Antisera ... strains
# nsubj_verb_dobj 	 included ... which ... species
# nsubj_verb_dobj 	 produced ... which ... lines
# nsubj_verb_dobj 	 gave ... antiserum ... cross-reactions
# nsubj_verb_dobj 	 gave ... DNA ... percentage
# nsubj_verb_dobj 	 gave ... DNA ... %
# nsubj_verb_dobj 	 indicate ... results ... homology
# nsubj_verb_dobj 	 isolate ... we ... pseudomonad
# nsubj_verb_dobj 	 divided ... syringae ... pseudomonads
# nsubj_verb_dobj 	 comprised ... I ... strains
# nsubj_verb_dobj 	 reduce ... Group ... nitrates
# nsubj_verb_dobj 	 reduce ... strains ... nitrates
# nsubj_verb_dobj 	 reduced ... strains ... nitrate
# nsubj_verb_dobj 	 contained ... Group ... strains
# nsubj_verb_dobj 	 contained ... that ... granules
# nsubj_verb_dobj 	 comprised ... Group ... strains
# nsubj_verb_dobj 	 includes ... which ... rubrilineans
# nsubj_verb_dobj 	 reduces ... avenae ... nitrate
# nsubj_verb_dobj 	 fits ... interaction ... description
# nsubj_verb_dobj 	 separated ... al. ... species
# nsubj_verb_dobj 	 characterized ... al. ... strains
# nsubj_verb_dobj 	 produced ... pigments ... reaction
# nsubj_verb_dobj 	 thank ... composition ... Donaldson
# nsubj_verb_dobj 	 thank ... We ... Donaldson
# nsubj_verb_dobj 	 showed ... pseudomonads ... fluorescence
# nsubj_verb_dobj 	 extended ... water ... upwards
# nsubj_verb_dobj 	 produced ... pseudomonads ... spots
# nsubj_verb_dobj 	 caused ... none ... symptoms
# nsubj_verb_dobj 	 caused ... None ... infections
# nsubj_verb_dobj 	 obtained ... who ... results
# nsubj_verb_dobj 	 caused ... solanacearum ... wilting
# nsubj_verb_dobj 	 cause ... crossabsorption ... decrease
# nsubj_verb_dobj 	 includes ... It ... groups
# nsubj_verb_dobj 	 provides ... scheme ... guidelines
# nsubj_verb_dobj 	 proposed ... scheme ... name
# nsubj_verb_dobj 	 gave ... Kondrat’eva ... culture
# nsubj_verb_dobj 	 brought ... I ... which
# nsubj_verb_dobj 	 examined ... Romano ... cultures
# nsubj_verb_dobj 	 grasp ... we ... significance
# nsubj_verb_dobj 	 named ... Gray ... limicola
# nsubj_verb_dobj 	 identified ... Pfennig ... organisms
# nsubj_verb_dobj 	 supports ... evidence ... classification
# nsubj_verb_dobj 	 contained ... K ... aestuarii
# nsubj_verb_dobj 	 designate ... I ... strain
# nsubj_verb_dobj 	 express ... We ... opposition
# nsubj_verb_dobj 	 justified ... Farmer ... proposal
# nsubj_verb_dobj 	 proposed ... They ... name
# nsubj_verb_dobj 	 proposed ... They ... anguillimortifera
# nsubj_verb_dobj 	 stated ... they ... which
# nsubj_verb_dobj 	 reach ... Bulletin ... bacteriologists
# nsubj_verb_dobj 	 invalidate ... this ... publication
# nsubj_verb_dobj 	 omitted ... Bergeyana ... anguillimortiferum
# nsubj_verb_dobj 	 gained ... it ... acceptance
# nsubj_verb_dobj 	 violate ... acceptance ... intent
# nsubj_verb_dobj 	 cite ... we ... examples
# nsubj_verb_dobj 	 gained ... epithets ... acceptance
# nsubj_verb_dobj 	 cited ... al. ... Opinion
# nsubj_verb_dobj 	 creates ... it ... it
# nsubj_verb_dobj 	 indicated ... Williams ... diameter
# nsubj_verb_dobj 	 included ... characteristics ... growth
# nsubj_verb_dobj 	 included ... characteristics ... occurrence
# nsubj_verb_dobj 	 emended ... Williams ... description
# nsubj_verb_dobj 	 possessed ... ATCC ... diameter
# nsubj_verb_dobj 	 caused ... strain ... acidification
# nsubj_verb_dobj 	 confirmed ... al. ... results
# nsubj_verb_dobj 	 possessed ... Cells ... turn
# nsubj_verb_dobj 	 possessed ... cells ... turns
# nsubj_verb_dobj 	 possessed ... cells ... flagellum
# nsubj_verb_dobj 	 possessed ... cells ... bipolar
# nsubj_verb_dobj 	 possessed ... cells ... flagella
# nsubj_verb_dobj 	 exhibited ... cells ... tufts
# nsubj_verb_dobj 	 possessed ... cells ... flagella
# nsubj_verb_dobj 	 revealed ... microscopy ... occurrence
# nsubj_verb_dobj 	 formed ... strains ... colonies
# nsubj_verb_dobj 	 formed ... 3 ... colonies
# nsubj_verb_dobj 	 caused ... strain ... acidification
# nsubj_verb_dobj 	 caused ... 2a ... acidification
# nsubj_verb_dobj 	 lists ... Tables ... responses
# nsubj_verb_dobj 	 used ... strains ... spectrum
# nsubj_verb_dobj 	 supported ... all ... growth
# nsubj_verb_dobj 	 allowed ... which ... strain
# nsubj_verb_dobj 	 indicated ... study ... response
# nsubj_verb_dobj 	 using ... Terasaki ... method
# nsubj_verb_dobj 	 exhibited ... Strains ... versatility
# nsubj_verb_dobj 	 included ... sources ... urea
# nsubj_verb_dobj 	 contained ... cultures ... contaminant
# nsubj_verb_dobj 	 employed ... ATCC ... freeze-drying
# nsubj_verb_dobj 	 employed ... NCMB ... L-drying
# nsubj_verb_dobj 	 represent ... strains ... strain
# nsubj_verb_dobj 	 indicate ... photomicrographs ... number
# nsubj_verb_dobj 	 yielded ... culture ... cells
# nsubj_verb_dobj 	 revealed ... examination ... presence
# nsubj_verb_dobj 	 indicated ... examination ... occurrence
# nsubj_verb_dobj 	 resembled ... that ... cells
# nsubj_verb_dobj 	 indicates ... comparison ... similarity
# nsubj_verb_dobj 	 include ... similarities ... dimensions
# nsubj_verb_dobj 	 exhibits ... maris ... configuration
# nsubj_verb_dobj 	 include ... Dissimilarities ... following
# nsubj_verb_dobj 	 possess ... strains ... deoxyribonuclease
# nsubj_verb_dobj 	 possess ... strains ... strains
# nsubj_verb_dobj 	 use ... maris ... number
# nsubj_verb_dobj 	 use ... 3 ... none
# nsubj_verb_dobj 	 use ... strains ... none
# nsubj_verb_dobj 	 represent ... dissimilarities ... differences
# nsubj_verb_dobj 	 propose ... we ... name
# nsubj_verb_dobj 	 retains ... name ... epithet
# nsubj_verb_dobj 	 possess ... species ... one
# nsubj_verb_dobj 	 possess ... delicatum ... shape
# nsubj_verb_dobj 	 exclude ... None ... strains
# nsubj_verb_dobj 	 carry ... they ... weight
# nsubj_verb_dobj 	 represent ... they ... genus
# nsubj_verb_dobj 	 await ... classification ... information
# nsubj_verb_dobj 	 issue ... Commission ... opinion
# nsubj_verb_dobj 	 studied ... Fitzgerald ... strains
# nsubj_verb_dobj 	 observed ... Koopman ... formation
# nsubj_verb_dobj 	 identified ... al. ... strains
# nsubj_verb_dobj 	 belonging ... sporeformers ... Clostridium
# nsubj_verb_dobj 	 isolated ... Sugihara ... strains
# nsubj_verb_dobj 	 isolated ... al. ... strains
# nsubj_verb_dobj 	 regarded ... authors ... organisms
# nsubj_verb_dobj 	 showed ... strains ... degrees
# nsubj_verb_dobj 	 distinguish ... features ... organisms
# nsubj_verb_dobj 	 distinguish ... features ... Bacillus
# nsubj_verb_dobj 	 produce ... they ... acid
# nsubj_verb_dobj 	 produce ... which ... acid
# nsubj_verb_dobj 	 identified ... al. ... strains
# nsubj_verb_dobj 	 consider ... who ... strains
# nsubj_verb_dobj 	 represent ... groups ... species
# nsubj_verb_dobj 	 represent ... groups ... Clostridium
# nsubj_verb_dobj 	 propose ... we ... cocleatum
# nsubj_verb_dobj 	 shows ... Table ... characteristics
# nsubj_verb_dobj 	 lost ... Cells ... characteristics
# nsubj_verb_dobj 	 contains ... one ... strains
# nsubj_verb_dobj 	 contains ... other ... strains
# nsubj_verb_dobj 	 reached ... bath ... temperature
# nsubj_verb_dobj 	 revealed ... Cultures ... forms
# nsubj_verb_dobj 	 survived ... strains ... heating
# nsubj_verb_dobj 	 measured ... Cells ... 0.4
# nsubj_verb_dobj 	 stained ... isolates ... negative
# nsubj_verb_dobj 	 formed ... strains ... spores
# nsubj_verb_dobj 	 included ... Group ... strains
# nsubj_verb_dobj 	 measured ... Cells ... 4
# nsubj_verb_dobj 	 showed ... They ... preponderance
# nsubj_verb_dobj 	 measured ... Cells ... 0.5
# nsubj_verb_dobj 	 show ... subcultures ... cells
# nsubj_verb_dobj 	 formed ... strains ... spores
# nsubj_verb_dobj 	 measured ... Cells ... 0.4
# nsubj_verb_dobj 	 measured ... Cells ... 0.4
# nsubj_verb_dobj 	 shows ... Table ... homologies
# nsubj_verb_dobj 	 showed ... levels ... degrees
# nsubj_verb_dobj 	 exhibited ... isolates ... degrees
# nsubj_verb_dobj 	 formed ... midpoints ... ATCC
# nsubj_verb_dobj 	 formed ... duplex ... ATCC
# nsubj_verb_dobj 	 include ... regions ... sequences
# nsubj_verb_dobj 	 confirmed ... findings ... appropriateness
# nsubj_verb_dobj 	 Produce ... Which ... Acid
# nsubj_verb_dobj 	 Produce ... Which ... Fermentationa
# nsubj_verb_dobj 	 hydrolyzes ... that ... linkages
# nsubj_verb_dobj 	 compared ... We ... actions
# nsubj_verb_dobj 	 produce ... coli ... materials
# nsubj_verb_dobj 	 reported ... al. ... method
# nsubj_verb_dobj 	 report ... they ... properties
# nsubj_verb_dobj 	 contains ... first ... pullulanases
# nsubj_verb_dobj 	 contains ... other ... pullulanases
# nsubj_verb_dobj 	 form ... lines ... spur
# nsubj_verb_dobj 	 produces ... which ... pullulanase
# nsubj_verb_dobj 	 conducted ... Hori ... study
# nsubj_verb_dobj 	 produced ... strains ... activity
# nsubj_verb_dobj 	 reported ... al. ... occurrence
# nsubj_verb_dobj 	 detected ... they ... pullulanase
# nsubj_verb_dobj 	 detect ... We ... pullulanase
# nsubj_verb_dobj 	 thank ... We ... Banno
# nsubj_verb_dobj 	 isolated ... who ... strain
# nsubj_verb_dobj 	 gave ... preparations ... line
# nsubj_verb_dobj 	 show ... Serum ... reaction
# nsubj_verb_dobj 	 investigated ... We ... utilization
# nsubj_verb_dobj 	 grew ... None ... S
# nsubj_verb_dobj 	 induces ... which ... pullulanase
# nsubj_verb_dobj 	 studied ... strains ... pullulanase
# nsubj_verb_dobj 	 produced ... none ... pullulanase
# nsubj_verb_dobj 	 showed ... none ... activity
# nsubj_verb_dobj 	 contained ... supernatants ... activity
# nsubj_verb_dobj 	 produce ... which ... pullulanase
# nsubj_verb_dobj 	 formed ... Those ... spur
# nsubj_verb_dobj 	 formed ... they ... spur
# nsubj_verb_dobj 	 possess ... pullulanases ... all
# nsubj_verb_dobj 	 gave ... extracts ... reactions
# nsubj_verb_dobj 	 provided ... capacity ... basis
# nsubj_verb_dobj 	 represented ... titer ... best
# nsubj_verb_dobj 	 gave ... which ... evidence
# nsubj_verb_dobj 	 bind ... enzyme ... antibody
# nsubj_verb_dobj 	 lost ... that ... activity
# nsubj_verb_dobj 	 suggest ... deviations ... heterogeneity
# nsubj_verb_dobj 	 provided ... addition ... advantages
# nsubj_verb_dobj 	 merits ... difference ... comment
# nsubj_verb_dobj 	 approximates ... sum ... scores
# nsubj_verb_dobj 	 represent ... convergence ... response
# nsubj_verb_dobj 	 suggests ... agreement ... stability
# nsubj_verb_dobj 	 reflect ... scores ... range
# nsubj_verb_dobj 	 occupy ... avium ... habitats
# nsubj_verb_dobj 	 follows ... substitution ... process
# nsubj_verb_dobj 	 follow ... occurrences ... process
# nsubj_verb_dobj 	 suggests ... convergence ... caution
# nsubj_verb_dobj 	 demonstrated ... al. ... overlap
# nsubj_verb_dobj 	 await ... evidence ... development
# nsubj_verb_dobj 	 received ... they ... ml
# nsubj_verb_dobj 	 received ... they ... µg
# nsubj_verb_dobj 	 contained ... antiserum ... activity
# nsubj_verb_dobj 	 destroy ... that ... µmol
# nsubj_verb_dobj 	 precipitate ... which ... unit
# nsubj_verb_dobj 	 exhibited ... that ... loss
# nsubj_verb_dobj 	 bore ... which ... name
# nsubj_verb_dobj 	 used ... who ... techniques
# nsubj_verb_dobj 	 blurred ... which ... division
# nsubj_verb_dobj 	 blurred ... “ ... division
# nsubj_verb_dobj 	 showed ... Strains ... values
# nsubj_verb_dobj 	 produce ... strains ... acid
# nsubj_verb_dobj 	 showed ... Strains ... values
# nsubj_verb_dobj 	 gave ... they ... reaction
# nsubj_verb_dobj 	 reduced ... Strain ... nitrate
# nsubj_verb_dobj 	 measured ... µm ... 0.8
# nsubj_verb_dobj 	 star”-shaped ... “ ... microcolonies
# nsubj_verb_dobj 	 showed ... microcolonies ... structure
# nsubj_verb_dobj 	 includes ... megaterium ... strains
# nsubj_verb_dobj 	 showed ... authors ... homology
# nsubj_verb_dobj 	 found ... we ... which
# nsubj_verb_dobj 	 possessed ... strains ... properties
# nsubj_verb_dobj 	 possessed ... Ten ... characters
# nsubj_verb_dobj 	 showed ... strains ... reactions
# nsubj_verb_dobj 	 showed ... strains ... ”
# nsubj_verb_dobj 	 examined ... who ... strains
# nsubj_verb_dobj 	 showed ... six ... characteristics
# nsubj_verb_dobj 	 allowed ... values ... division
# nsubj_verb_dobj 	 corroborated ... data ... observations
# nsubj_verb_dobj 	 show ... values ... division
# nsubj_verb_dobj 	 utilize ... strain ... any
# nsubj_verb_dobj 	 exhibited ... colony ... intermediate
# nsubj_verb_dobj 	 showed ... strains ... growth
# nsubj_verb_dobj 	 showed ... mutant ... growth
# nsubj_verb_dobj 	 obtained ... mutants ... glucose
# nsubj_verb_dobj 	 showed ... mutants ... characters
# nsubj_verb_dobj 	 showed ... P2-R1-N4 ... coefficient
# nsubj_verb_dobj 	 showed ... P2-R1-N7 ... one
# nsubj_verb_dobj 	 gordonae ... Mycobacterium ... Bojalil
# nsubj_verb_dobj 	 delivered ... that ... sample
# nsubj_verb_dobj 	 indicate ... numbers ... number
# nsubj_verb_dobj 	 represent ... Pl ... mutants
# nsubj_verb_dobj 	 represent ... Pl ... strain
# nsubj_verb_dobj 	 accompanies ... mutation ... mutations
# nsubj_verb_dobj 	 caused ... mutation ... decrease
# nsubj_verb_dobj 	 produce ... mutation ... changes
# nsubj_verb_dobj 	 caused ... mutation ... alteration
# nsubj_verb_dobj 	 share ... which ... antigens
# nsubj_verb_dobj 	 show ... they ... coefficients
# nsubj_verb_dobj 	 raises ... finding ... question
# nsubj_verb_dobj 	 made ... members ... recommendations
# nsubj_verb_dobj 	 produced ... strains ... rise
# nsubj_verb_dobj 	 placed ... property ... strains
# nsubj_verb_dobj 	 gave ... mycoplasma ... reaction
# nsubj_verb_dobj 	 summarizes ... paper ... characteristics
# nsubj_verb_dobj 	 represents ... it ... species
# nsubj_verb_dobj 	 involved ... that ... swabbing
# nsubj_verb_dobj 	 metabolized ... all ... arginine
# nsubj_verb_dobj 	 gave ... test ... evidence
# nsubj_verb_dobj 	 produced ... equirhinis ... phenomenon
# nsubj_verb_dobj 	 indicates ... Comparison ... this
# ...
# nsubj_verb_dobj 	 casting ... discoveries ... doubt
# nsubj_verb_dobj 	 confirms ... evidence ... claim
# nsubj_verb_dobj 	 extended ... populations ... range
# nsubj_verb_dobj 	 included ... varieties ... one
# nsubj_verb_dobj 	 produced ... which ... lesions
# nsubj_verb_dobj 	 affect ... varieties ... humans
# nsubj_verb_dobj 	 affected ... form ... humans
# nsubj_verb_dobj 	 display ... groups ... it
# nsubj_verb_dobj 	 make ... I ... point
# nsubj_verb_dobj 	 left ... which ... evidence
# nsubj_verb_dobj 	 overlap ... they ... that
# nsubj_verb_dobj 	 overlap ... they ... ”
# nsubj_verb_dobj 	 gives ... Figure ... alternative
# nsubj_verb_dobj 	 positioning ... difference ... T.
# nsubj_verb_dobj 	 causes ... treponeme ... lesions
# nsubj_verb_dobj 	 contradict ... facts ... scheme
# nsubj_verb_dobj 	 offers ... skin ... temperature
# nsubj_verb_dobj 	 establishes ... it ... itself
# nsubj_verb_dobj 	 suggest ... which ... distance
# nsubj_verb_dobj 	 postulate ... one ... occurrence
# nsubj_verb_dobj 	 explain ... This ... occurrence
# nsubj_verb_dobj 	 undergone ... yaws ... evolution
# nsubj_verb_dobj 	 place ... method ... them
# nsubj_verb_dobj 	 suggest ... I ... replacement
# nsubj_verb_dobj 	 lacks ... it ... layers
# nsubj_verb_dobj 	 avoid ... use ... situations
# nsubj_verb_dobj 	 contain ... groups ... species
# nsubj_verb_dobj 	 contain ... DSM ... lipopolysac-charide
# nsubj_verb_dobj 	 suggests ... author ... use
# nsubj_verb_dobj 	 suggests ... author ... reaction
# nsubj_verb_dobj 	 listed ... They ... genera
# nsubj_verb_dobj 	 tested ... we ... relatedness
# nsubj_verb_dobj 	 studied ... Behrens ... relatedness
# nsubj_verb_dobj 	 studied ... Pohl ... relatedness
# nsubj_verb_dobj 	 provides ... lack ... basis
# nsubj_verb_dobj 	 showed ... DNA ... reassociation
# nsubj_verb_dobj 	 showed ... DNAs ... reaction
# nsubj_verb_dobj 	 indicates ... relatedness ... species
# nsubj_verb_dobj 	 experienced ... We ... difficulties
# nsubj_verb_dobj 	 support ... results ... classification
# nsubj_verb_dobj 	 exhibited ... Some ... differences
# nsubj_verb_dobj 	 reports ... paper ... results
# nsubj_verb_dobj 	 i-inositolum ... Glucosum ... assimilantur
# nsubj_verb_dobj 	 i-inositolum ... et ... assimilantur
# nsubj_verb_dobj 	 necessariae ... crescentiam ... sunt
# nsubj_verb_dobj 	 measure ... Growth ... 6.0
# nsubj_verb_dobj 	 contain ... which ... ascospores
# nsubj_verb_dobj 	 dies ... post ... dominantes
# nsubj_verb_dobj 	 iodophila ... amyloidea ... formatur
# nsubj_verb_dobj 	 required ... Vitamin ... thiamine
# nsubj_verb_dobj 	 showed ... sections ... wall
# nsubj_verb_dobj 	 yielded ... treatment ... cultures
# nsubj_verb_dobj 	 represent ... all ... type
# nsubj_verb_dobj 	 require ... they ... conditions
# nsubj_verb_dobj 	 produced ... isolates ... neoformans
# nsubj_verb_dobj 	 produced ... those ... bacillispora
# nsubj_verb_dobj 	 evolved ... neoformans ... mechanism
# nsubj_verb_dobj 	 causes ... bacillisporus ... %
# nsubj_verb_dobj 	 produced ... intercross ... basidiospores
# nsubj_verb_dobj 	 report ... We ... results
# nsubj_verb_dobj 	 includes ... Filobasidiella ... species
# nsubj_verb_dobj 	 explain ... factors ... discrepancies
# nsubj_verb_dobj 	 utilized ... investigators ... techniques
# nsubj_verb_dobj 	 yielded ... method ... DNA
# nsubj_verb_dobj 	 utilized ... Erke ... pressures
# nsubj_verb_dobj 	 yield ... methodology ... estimates
# nsubj_verb_dobj 	 revealed ... analysis ... groups
# nsubj_verb_dobj 	 possess ... isolates ... homology
# nsubj_verb_dobj 	 characterize ... values ... species
# nsubj_verb_dobj 	 detect ... studies ... evidence
# nsubj_verb_dobj 	 contained ... mixtures ... µg
# nsubj_verb_dobj 	 denotes ... Specifically,,,,where ... hybridization
# nsubj_verb_dobj 	 denotes ... A*B ... hybridization
# nsubj_verb_dobj 	 yielded ... which ... amount
# nsubj_verb_dobj 	 ranged ... Tm(e ... C
# nsubj_verb_dobj 	 averaged ... Tm(e ... C
# nsubj_verb_dobj 	 represent ... calculated ... estimates
# nsubj_verb_dobj 	 performed ... we ... series
# nsubj_verb_dobj 	 ranged ... Tm(e ... C
# nsubj_verb_dobj 	 depicts ... Figure ... results
# nsubj_verb_dobj 	 approached ... self-hybridization ... %
# nsubj_verb_dobj 	 exhibited ... DNA ... homology
# nsubj_verb_dobj 	 contain ... Sequences ... regions
# nsubj_verb_dobj 	 displays ... Table ... Tm(e
# nsubj_verb_dobj 	 displays ... Table ... ’s
# nsubj_verb_dobj 	 demonstrated ... Heteroduplexes ... differences
# nsubj_verb_dobj 	 carry ... minutes ... statements
# nsubj_verb_dobj 	 reaffirmed ... Commission ... policy
# nsubj_verb_dobj 	 reverse ... “ ... Opinion
# nsubj_verb_dobj 	 conserved ... which ... Enterobacteriaceae
# nsubj_verb_dobj 	 conserved ... which ... Escherichia
# nsubj_verb_dobj 	 carried ... issue ... proposal
# nsubj_verb_dobj 	 examined ... Commission ... questions
# nsubj_verb_dobj 	 contained ... which ... species
# nsubj_verb_dobj 	 conserve ... Commission ... genera
# nsubj_verb_dobj 	 issue ... Commission ... opinion
# nsubj_verb_dobj 	 thank ... We ... Holt
# nsubj_verb_dobj 	 contains ... It ... presentations
# nsubj_verb_dobj 	 reflects ... title ... contents
# nsubj_verb_dobj 	 provides ... Norris ... anecdote
# nsubj_verb_dobj 	 informed ... scientist ... Pasteur
# nsubj_verb_dobj 	 excites ... that ... me
# nsubj_verb_dobj 	 likens ... he ... more
# nsubj_verb_dobj 	 organizes ... Norris ... procedures
# nsubj_verb_dobj 	 contributed ... who ... first
# nsubj_verb_dobj 	 attended ... Bradley ... symposium
# nsubj_verb_dobj 	 reviews ... he ... approaches
# nsubj_verb_dobj 	 allow ... plasmids ... bacteria
# nsubj_verb_dobj 	 alter ... characteristics ... bacteria
# nsubj_verb_dobj 	 discusses ... chapter ... utility
# nsubj_verb_dobj 	 written ... Jones ... paper
# nsubj_verb_dobj 	 discusses ... analysis ... use
# nsubj_verb_dobj 	 deserves ... comment ... response
# nsubj_verb_dobj 	 disproves ... exception ... rule
# nsubj_verb_dobj 	 compares ... which ... features
# nsubj_verb_dobj 	 contributed ... Hammann ... chapter
# nsubj_verb_dobj 	 liked ... I ... chapter
# nsubj_verb_dobj 	 discuss ... Billing ... typing
# nsubj_verb_dobj 	 include ... pages ... abstracts
# nsubj_verb_dobj 	 contains ... It ... lot
# nsubj_verb_dobj 	 taxes ... complexity ... classification
# nsubj_verb_dobj 	 accomplishes ... It ... purposes
# nsubj_verb_dobj 	 provides ... it ... review
# nsubj_verb_dobj 	 provides ... it ... exhibition
# nsubj_verb_dobj 	 include ... Techniques ... homology
# nsubj_verb_dobj 	 include ... latter ... spp
# nsubj_verb_dobj 	 contain ... Nocardiae ... acid
# nsubj_verb_dobj 	 contain ... arthro-bacters ... meso-DAP
# nsubj_verb_dobj 	 contain ... corynebacteria ... component
# nsubj_verb_dobj 	 contain ... acids ... proportions
# nsubj_verb_dobj 	 contain ... corynebacteria ... acid
# nsubj_verb_dobj 	 used ... we ... fraction
# nsubj_verb_dobj 	 detected ... spots ... NCTC
# nsubj_verb_dobj 	 contain ... those ... carbons
# nsubj_verb_dobj 	 contains ... divaricatum ... analogs
# nsubj_verb_dobj 	 contains ... divaricatum ... carbons
# nsubj_verb_dobj 	 occupies ... LCN-A ... position
# nsubj_verb_dobj 	 contained ... strains ... meso-DAP
# nsubj_verb_dobj 	 showed ... Smears ... rods
# nsubj_verb_dobj 	 formed ... latter ... forms
# nsubj_verb_dobj 	 raised ... that ... centers
# nsubj_verb_dobj 	 oxidized ... All ... glucose
# nsubj_verb_dobj 	 became ... milk ... alkaline
# nsubj_verb_dobj 	 classify ... we ... organisms
# nsubj_verb_dobj 	 produce ... fragments ... colonies
# nsubj_verb_dobj 	 compared ... We ... properties
# nsubj_verb_dobj 	 found ... we ... nothing
# nsubj_verb_dobj 	 based ... author ... description
# nsubj_verb_dobj 	 assigned ... authors ... strain
# nsubj_verb_dobj 	 assigned ... authors ... rhodochrous
# nsubj_verb_dobj 	 assigned ... authors ... ”
# nsubj_verb_dobj 	 utilize ... isolates ... benzoate
# nsubj_verb_dobj 	 peptonize ... bacteria ... milk
# nsubj_verb_dobj 	 regard ... we ... luteum
# nsubj_verb_dobj 	 serve ... it ... purpose
# nsubj_verb_dobj 	 propose ... we ... name
# nsubj_verb_dobj 	 regard ... We ... luteus
# nsubj_verb_dobj 	 require ... use ... amendment
# nsubj_verb_dobj 	 produces ... similar ... urease
# nsubj_verb_dobj 	 produces ... IMV ... urease
# nsubj_verb_dobj 	 decomposes ... IMV ... hypoxanthine
# nsubj_verb_dobj 	 contained ... strains ... meso-DAP
# nsubj_verb_dobj 	 possessed ... Strain ... MK-8(H2
# nsubj_verb_dobj 	 resemble ... strains ... mans”&gt
# nsubj_verb_dobj 	 contains ... linens ... ribose
# nsubj_verb_dobj 	 propose ... we ... name
# nsubj_verb_dobj 	 oxidize ... rhodococci ... glucose
# nsubj_verb_dobj 	 provided ... who ... strains
# nsubj_verb_dobj 	 thank ... we ... Lessel
# nsubj_verb_dobj 	 giving ... 587,Tests ... results
# nsubj_verb_dobj 	 giving ... B-464,Tests ... results
# nsubj_verb_dobj 	 lumped ... taxonomists ... them
# nsubj_verb_dobj 	 produce ... strains ... amounts
# nsubj_verb_dobj 	 produce ... that ... amounts
# nsubj_verb_dobj 	 undertaken ... we ... analyses
# nsubj_verb_dobj 	 contain ... micrococci ... acid
# nsubj_verb_dobj 	 exhibit ... micrococci ... color
# nsubj_verb_dobj 	 produced ... ATCC ... acid
# nsubj_verb_dobj 	 produced ... ATCC ... acid
# nsubj_verb_dobj 	 showed ... acid ... composition
# nsubj_verb_dobj 	 contained ... They ... amounts
# nsubj_verb_dobj 	 support ... results ... transfer
# nsubj_verb_dobj 	 support ... results ... ATCC
# nsubj_verb_dobj 	 contains ... which ... aldolase
# nsubj_verb_dobj 	 indicate ... base ... relationship
# nsubj_verb_dobj 	 resemble ... ATCC ... sciuri
# nsubj_verb_dobj 	 indicated ... studies ... relationship
# nsubj_verb_dobj 	 demonstrated ... Comparison ... relationship
# nsubj_verb_dobj 	 investigated ... staphylococci ... form
# nsubj_verb_dobj 	 produced ... strains ... acid
# nsubj_verb_dobj 	 produced ... strain ... acid
# nsubj_verb_dobj 	 contain ... they ... amounts
# nsubj_verb_dobj 	 requires ... characterization ... techniques
# nsubj_verb_dobj 	 contain ... Bacteroideis ... sphingolipids
# nsubj_verb_dobj 	 contain ... species ... pattern
# nsubj_verb_dobj 	 analyzed ... al. ... strains
# nsubj_verb_dobj 	 constructed ... authors ... dendrogram
# nsubj_verb_dobj 	 report ... We ... study
# nsubj_verb_dobj 	 indicates ... report ... utility
# nsubj_verb_dobj 	 included ... Sources ... Collection
# nsubj_verb_dobj 	 comprised ... classes ... %
# nsubj_verb_dobj 	 contained ... Strains ... quantities
# nsubj_verb_dobj 	 contained ... strains ... concentrations
# nsubj_verb_dobj 	 permitted ... which ... separation
# nsubj_verb_dobj 	 showed ... which ... ratios
# nsubj_verb_dobj 	 tend ... melaninogenicus ... ratios
# nsubj_verb_dobj 	 contained ... strains ... acid
# nsubj_verb_dobj 	 showed ... 5 ... a17h
# nsubj_verb_dobj 	 indicate ... deviations ... variability
# nsubj_verb_dobj 	 demonstrated ... Lambe ... serogroups
# nsubj_verb_dobj 	 demonstrated ... Lambe ... intermedius
# nsubj_verb_dobj 	 led ... Heterogeneity ... al.
# nsubj_verb_dobj 	 contained ... levii ... acid
# nsubj_verb_dobj 	 distinguished ... this ... it
# nsubj_verb_dobj 	 contained ... which ... amounts
# nsubj_verb_dobj 	 contained ... strains ... levels
# nsubj_verb_dobj 	 indicate ... separations ... usefulness
# nsubj_verb_dobj 	 produce ... which ... pigment
# nsubj_verb_dobj 	 includes ... which ... strains
# nsubj_verb_dobj 	 support ... ratios ... recognition
# nsubj_verb_dobj 	 provide ... determination ... information
# nsubj_verb_dobj 	 separates ... calculation ... most
# nsubj_verb_dobj 	 show ... asaccharolyticus ... similarity
# nsubj_verb_dobj 	 show ... asaccharolyticus ... similarity
# nsubj_verb_dobj 	 permitted ... use ... separation
# nsubj_verb_dobj 	 confirm ... profiles ... identification
# nsubj_verb_dobj 	 provided ... who ... us
# nsubj_verb_dobj 	 thank ... We ... Holdeman
# nsubj_verb_dobj 	 supported ... data ... divisions
# nsubj_verb_dobj 	 relegated ... experiments ... cuniculi
# nsubj_verb_dobj 	 contradicted ... data ... finding
# nsubj_verb_dobj 	 describes ... paper ... comparisons
# nsubj_verb_dobj 	 contained ... injections ... ml
# nsubj_verb_dobj 	 produce ... that ... precipitates
# nsubj_verb_dobj 	 produce ... Groups ... reaction
# nsubj_verb_dobj 	 comprise ... reactions ... groups
# nsubj_verb_dobj 	 relegated ... cross-matches ... species
# nsubj_verb_dobj 	 produced ... Antisera ... precipitates
# nsubj_verb_dobj 	 produced ... trans-aldolases ... precipitates
# nsubj_verb_dobj 	 exhibited ... longum ... degree
# nsubj_verb_dobj 	 exceeded ... differences ... shift
# nsubj_verb_dobj 	 form ... transaldolase ... bridge
# nsubj_verb_dobj 	 exhibited ... it ... similarity
# nsubj_verb_dobj 	 shared ... species ... degree
# nsubj_verb_dobj 	 contain ... clusters ... species
# nsubj_verb_dobj 	 form ... species ... small
# nsubj_verb_dobj 	 form ... insects ... small
# nsubj_verb_dobj 	 provide ... they ... line
# nsubj_verb_dobj 	 reflect ... subdivision ... history
# nsubj_verb_dobj 	 attack ... Members ... carbohydrates
# nsubj_verb_dobj 	 included ... genus ... cocci
# nsubj_verb_dobj 	 contained ... broth ... g
# nsubj_verb_dobj 	 contained ... it ... salts
# nsubj_verb_dobj 	 contained ... it ... sulfoxalate
# nsubj_verb_dobj 	 contain ... lysate ... borate
# nsubj_verb_dobj 	 explains ... variation ... lack
# nsubj_verb_dobj 	 received ... who ... it
# nsubj_verb_dobj 	 give ... cultures ... patterns
# nsubj_verb_dobj 	 ferment ... strains ... glucose
# nsubj_verb_dobj 	 lowered ... Nine ... pH
# nsubj_verb_dobj 	 ferment ... veillonel-lae ... carbohydrates
# nsubj_verb_dobj 	 required ... cultures ... putrescine
# nsubj_verb_dobj 	 stimulated ... additives ... growth
# nsubj_verb_dobj 	 stimulated ... Vitamins ... growth
# nsubj_verb_dobj 	 ferment ... they ... carbohydrates
# nsubj_verb_dobj 	 attack ... strains ... intermediates
# nsubj_verb_dobj 	 designate ... serovars ... species
# nsubj_verb_dobj 	 showed ... 112 ... level
# nsubj_verb_dobj 	 indicates ... that ... differences
# nsubj_verb_dobj 	 recognizing ... we ... group
# nsubj_verb_dobj 	 represent ... These ... species
# nsubj_verb_dobj 	 gave ... enzymes ... cross-reactions
# nsubj_verb_dobj 	 fermented ... strains ... fructose
# nsubj_verb_dobj 	 described ... Strains ... species
# nsubj_verb_dobj 	 described ... values ... species
# nsubj_verb_dobj 	 described ... we ... species
# nsubj_verb_dobj 	 hydrolyzed ... that ... starch
# nsubj_verb_dobj 	 elaborated ... species ... enzymes
# nsubj_verb_dobj 	 involved ... modification ... use
# nsubj_verb_dobj 	 include ... which ... values
# nsubj_verb_dobj 	 contained ... that ... ml
# nsubj_verb_dobj 	 contained ... walls ... galactose
# nsubj_verb_dobj 	 show ... Experiments ... linkage
# nsubj_verb_dobj 	 contain ... walls ... acid
# nsubj_verb_dobj 	 cross-links ... which ... subunits
# nsubj_verb_dobj 	 employed ... study ... method
# nsubj_verb_dobj 	 permit ... procedures ... examination
# nsubj_verb_dobj 	 showed ... strains ... variation
# nsubj_verb_dobj 	 produced ... L. ... acid
# nsubj_verb_dobj 	 produces ... amylovorus ... acid
# nsubj_verb_dobj 	 produce ... that ... acid
# nsubj_verb_dobj 	 suggest ... Similarities ... relationship
# nsubj_verb_dobj 	 ferment ... Four ... fructose
# nsubj_verb_dobj 	 indicate ... values ... lack
# nsubj_verb_dobj 	 shares ... it ... similarities
# nsubj_verb_dobj 	 showed ... study ... absence
# nsubj_verb_dobj 	 thank ... requests ... Cavins
# nsubj_verb_dobj 	 thank ... Nakamura ... Cavins
# nsubj_verb_dobj 	 thank ... I ... Cavins
# nsubj_verb_dobj 	 reported ... reassociation ... isolation
# nsubj_verb_dobj 	 isolated ... Gardner ... bacterium
# nsubj_verb_dobj 	 carried ... Piot ... study
# nsubj_verb_dobj 	 supported ... results ... creation
# nsubj_verb_dobj 	 defined ... Greenwood ... vaginalis
# nsubj_verb_dobj 	 present ... we ... data
# nsubj_verb_dobj 	 contained ... strains ... glucose
# nsubj_verb_dobj 	 contains ... type ... acids
# nsubj_verb_dobj 	 contains ... peptidoglycan ... acids
# nsubj_verb_dobj 	 studied ... workers ... correlation
# nsubj_verb_dobj 	 examined ... Vickerstaff ... acid
# nsubj_verb_dobj 	 identify ... authors ... strains
# nsubj_verb_dobj 	 examined ... Criswell ... content
# nsubj_verb_dobj 	 contained ... bacterium ... range
# nsubj_verb_dobj 	 found ... authors ... lysine
# nsubj_verb_dobj 	 examined ... who ... organisms
# nsubj_verb_dobj 	 contains ... wall ... alanine
# nsubj_verb_dobj 	 contain ... wall ... DAP
